# %%
import pickle
import numpy as np
import utility as utl
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
def rolling_corr(data, window):
    start = 0
    corr_series = np.empty([data.shape[0]-window, data.shape[1], data.shape[1]])
    while start+window < data.shape[0]:
        data_window = data.iloc[start:start+window]
        corr_series[start, :, :] = np.corrcoef(data_window, rowvar=0)
        start += 1
    return corr_series

# %%
stocklist = 'nyse'
std_threshold = 0.2
window = 50

# %%
symbols, prices, dates = pickle.load(open("data/" + stocklist + "-prices.pkl", "rb"))
prices = prices.div(prices.iloc[0])
corr_series = utl.rolling_corr(prices, window) # corr_series is TxNxN matrix (T: dates, N: stocks)
corr_std = np.std(corr_series, 0) # corr_std is NxN matrix
corr_std[np.triu_indices(corr_std.shape[0])] = np.NaN # since matrix is symmetric, ignore upper triangle
indices = np.where(corr_std < std_threshold) # find those stock pairs with low correlation std dev

# %%
print("Total of %d stock in Oil & Gas Production industry from NYSE." % symbols.shape[0])
print("Date Range: form " + str(dates.min(0)) + " to " + str(dates.max(0)))
# Out:
# Total of 91 stock in Oil & Gas Production industry from NYSE.
# Date Range: form 2012-01-03 to 2015-09-01

# %%
# plotting
for i in range(0, len(indices[0])):
    j1 = indices[0][i]
    j2 = indices[1][i]
    ticker1 = symbols[j1]
    ticker2 = symbols[j2]
    corr_stocks = pd.Series(corr_series[:, j1, j2], index=dates[window:])
    
    plt.figure(i,figsize=(15, 5))
    plt.subplot(121)
    plt.plot(dates[:-window], corr_stocks)
    plt.ylabel('correlation')
    plt.xlabel('time')
    plt.title("std(" + ticker1 + ", " + ticker2 + ") = " + "{0:.4f}".format(corr_std[j1,j2]))
    plt.grid()
    plt.subplot(122)
    # plt.scatter(prices.iloc[j1], prices.iloc[j2], marker=".")
    plt.plot(dates, prices.iloc[:,j1], 'b', dates, prices.iloc[:,j2], 'r')
    plt.xlabel(ticker1)
    plt.ylabel(ticker2)
    plt.grid()
    plt.show()
